# %% [markdown]
# # Programming Homework 4
# ### Name: Patrycja Przewoźnik, Uni: pap2154

# %% [markdown]
# Submission Instructions:
#
# File > Print > Save As... > Save as PDF > Upload to GradeScope > Assign Pages

# %%
# Use IPython Image to display screenshots, NOT embedded HTML
from IPython.display import Image

# %% [markdown]
# #### POST /api/forums
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:52:35] "POST /api/forums HTTP/1.1" 201 -
# ```

# %%
#Screenshot
Image('mongoCompassPOSTforums.png')

# %%
#Screenshot
Image('mongoPOSTforums.png')

# %% [markdown]
# #### GET /api/forums
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:21:33] "GET /api/forums HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforums.png')

# %% [markdown]
# #### GET /api/forums?qs
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:28:23] "GET /api/forums?folders=HW1 HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforumsQ.png')

# %% [markdown]
# #### GET /api/forums/post_id
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:31:00] "GET /api/forums/31db189c-f5f5-4d3e-a3b5-4f5514b40925 HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforumspost_id.png')

# %% [markdown]
# #### GET /api/forums/post_id?qs
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:33:41] "GET /api/forums/31db189c-f5f5-4d3e-a3b5-4f5514b40925?folders=HW1 HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforumspost_idQ.png')

# %% [markdown]
# #### GET /api/forums/post_id/comments/comment_id
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:35:50] "GET /api/forums/31db189c-f5f5-4d3e-a3b5-4f5514b40925/comments/32095edc-18f0-4c55-8f55-b9d14cd7efd0 HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforumscomment_id.png')

# %% [markdown]
# #### GET /api/forums/post_id/comments/comment_id?qs
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:43:16] "GET /api/forums/31db189c-f5f5-4d3e-a3b5-4f5514b40925/comments/32095edc-18f0-4c55-8f55-b9d14cd7efd0?children.response_date=4/26/2020 HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforumscomment_idQ.png')

# %% [markdown]
# #### GET /api/forums/post_id/comments
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:46:06] "GET /api/forums/31db189c-f5f5-4d3e-a3b5-4f5514b40925/comments HTTP/1.1" 200 -
# ```

# %%
#Screenshot
Image('mongoGETforumscomments.png')

# %% [markdown]
# #### POST /api/forums/post_id/comments
# Text:
# ```
# 127.0.0.1 - - [15/Apr/2021 19:58:13] "POST /api/forums/08858bfb-9e1f-4690-a55b-53d34efda015/comments HTTP/1.1" 201 -
# ```

# %%
#Screenshot
Image('mongoCompassPOSTcomments.png')

# %%
#Screenshot
Image('mongoPOSTcomments.png')

# %% [markdown]
# #### GET /api/forums/post_id/comments?qs
# Text:
#     ```
#     127.0.0.1 - - [15/Apr/2021 19:49:40] "GET /api/forums/31db189c-f5f5-4d3e-a3b5-4f5514b40925/comments?children.response_date=8/22/2020 HTTP/1.1" 200 -
#     ```

# %%
#Screenshot
Image('mongoGETforumscommentsQ.png')
